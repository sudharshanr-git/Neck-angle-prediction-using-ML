# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from tensorflow.keras.layers import Input, Dense, Concatenate
tf.config.threading.set_inter_op_parallelism_threads(12)

# %%
input_data = Input(shape=(264,))
activation = Dense(264, activation='relu')(input_data)
activation = Dense(264, activation='relu')(input_data)
activation = Dense(128, activation='relu')(activation)
activation = Dense(128, activation='relu')(activation)
activation = Dense(64, activation='relu')(activation)
activation = Dense(32, activation='relu')(activation)

output = Dense(1, activation='linear')(activation)

model = tf.keras.Model(inputs=input_data, outputs=output)
model.compile(loss=tf.keras.losses.MeanSquaredError(), optimizer='adam', metrics=['accuracy'])#learning_rate=learning_rate
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 264)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_12 (Dense)                     │ (None, 264)                 │          69,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_13 (Dense)                     │ (None, 128)                 │          33,920 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 128)                 │          16,512 │
# ...

# %%
df=pd.read_csv('C:\\Users\\RS7un\\OneDrive\\Desktop\\Projects\\neck device\\code\\degree regression\\turn_train_crop_some.csv')
print(df)
df_test=pd.read_csv('C:\\Users\\RS7un\\OneDrive\\Desktop\\Projects\\neck device\\code\\degree regression\\turn_test_crop_some.csv')
print(df_test)
# Out:
#             1         2         3         4         5         6         7  \
# 0    0.501104  0.674385  0.492926  0.539467  0.496828  0.575965  0.490898
# 1    0.504760  0.674559  0.496868  0.543618  0.500242  0.579144  0.494739
# 2    0.504903  0.681252  0.496698  0.548077  0.500789  0.583894  0.494543
# 3    0.500379  0.671331  0.491694  0.540087  0.495712  0.576113  0.489668
# 4    0.512961  0.679398  0.504555  0.549768  0.508352  0.585467  0.502657
# ..        ...       ...       ...       ...       ...       ...       ...
# 783  0.078966  0.655737  0.023584  0.521857  0.103092  0.573176  0.022315
# 784  0.077547  0.639475  0.019596  0.506662  0.100750  0.557110  0.017747
# 785  0.073300  0.639283  0.018356  0.510673  0.098334  0.559876  0.015805
# 786  0.073300  0.639283  0.018356  0.510673  0.098334  0.559876  0.015805
# 787  0.073300  0.639283  0.018356  0.510673  0.098334  0.559876  0.015805
#
#             8         9        10  ...       256       257       258  \
# ...

# %%
X = df.iloc[:, :-1].values
Y = df.iloc[:, -1].values
print(X)
print(Y)

X_test = df_test.iloc[:, :-1].values
Y_test = df_test.iloc[:, -1].values
print(X_test)
print(Y_test)
# Out:
# [[0.50110382 0.67438459 0.49292609 ... 0.37840536 0.76160562 0.2809774 ]
#  [0.50475985 0.67455876 0.49686825 ... 0.37934429 0.76552236 0.28757784]
#  [0.50490254 0.68125218 0.49669766 ... 0.38391972 0.7677052  0.29021108]
#  ...
#  [0.07330012 0.63928253 0.01835552 ... 0.47849849 0.45793089 0.32780674]
#  [0.07330012 0.63928253 0.01835552 ... 0.47849849 0.45793089 0.32780674]
#  [0.07330012 0.63928253 0.01835552 ... 0.47849849 0.45793089 0.32780674]]
# [ -6  12   9  -3   6   9   9   3   6   9  12   6  12   9   6   3   0   3
#    0  -3  -6  -3  -6  -9 -11 -11 -15 -21 -29 -29 -32 -38 -47 -47 -47 -56
#  -60 -63 -56 -65 -71 -71 -81 -81 -77 -84 -84 -90 -87 -90 -87 -84 -84 -84
#  -84 -84 -84 -87 -87 -93 -87 -87 -90 -84 -84 -74 -63 -63 -63 -60 -50 -47
#  -38 -35 -35 -27 -27 -21 -18 -18 -15 -15  -6  -6  -3  -3   0   0   0   9
#    9  -6  -6   0   0   3   3  10  10  20  33  29  40  43  46  46  53  56
#   60  69  66  69  66  73  73  73  73  73  73  73  79  86  86  90  93  93
# ...

# %%
history = model.fit(
    X,
    Y,
    epochs=1000,
    batch_size=32,
    validation_data=(X_test, Y_test)
)

loss, accuracy = model.evaluate(X_test, Y_test)
print("Validation Loss:", loss)
print("Validation Accuracy:", accuracy)
# Out:
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 3s 17ms/step - accuracy: 0.0360 - loss: 2834.3826 - val_accuracy: 0.0068 - val_loss: 2317.9976
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0218 - loss: 686.2632 - val_accuracy: 0.0068 - val_loss: 583.9357
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0439 - loss: 192.0173 - val_accuracy: 0.0068 - val_loss: 355.3921
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.0218 - loss: 127.6579 - val_accuracy: 0.0068 - val_loss: 347.4448
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.0210 - loss: 122.1997 - val_accuracy: 0.0068 - val_loss: 412.5535
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.0277 - loss: 103.9399 - val_accuracy: 0.0068 - val_loss: 365.0721
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.0246 - loss: 95.0078 - val_accuracy: 0.0068 - val_loss: 379.5856
# Epoch 8/1000
# ...
